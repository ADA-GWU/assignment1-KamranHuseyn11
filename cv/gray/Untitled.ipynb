# %%
hsb_day.save("./hsb/hsb_day.jpg")
hsb_night.save("./hsb/hsb_night.jpg")
hsb_bright.save("./hsb/hsb_bright.jpg")
hsb_dim.save("./hsb/hsb_dim.jpg")

# %%
fig = plt.figure(figsize=(16, 24))
columns = 2
rows = 2


a = fig.add_subplot(2,2,1)
a.set_title("nightLight_Noon",fontdict={'fontsize': 20})
plt.imshow(hsb_night,cmap="gray")

b = fig.add_subplot(2,2,2)
b.set_title("nightLight_Evening",fontdict={'fontsize': 20})
plt.imshow(hsb_night,cmap="gray")
  
c = fig.add_subplot(2,2,3)
c.set_title("Bright_Fluorescent",fontdict={'fontsize': 20})
plt.imshow(hsb_bright,cmap="gray")

d = fig.add_subplot(2,2,4)
d.set_title("Dim_Fluorescent",fontdict={'fontsize': 20})
plt.imshow(hsb_dim,cmap="gray")

plt.show()
